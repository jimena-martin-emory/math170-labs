# %% [markdown]
# # Lab 1: Getting Set Up
#
# **MATH 170 — Introduction to Scientific Computing**
# **Fall 2026**
#
# You should already have worked through **Steps 1–5 in this folder's
# [README](README.md)** — a GitHub account, Python, an editor, Git, and your own
# repository. If you are reading this inside your `math170-yourname` folder, you
# have them.
#
# This notebook is Step 6:
#
# - Confirm the notebook is using your Python
# - Run the code we are giving you
#
# Then return to the README for **Step 7** (save to GitHub) and **Step 8**
# (submit on Gradescope).
#
# **You are given the answer.** `calculator.py` is finished, working code. You are
# not writing anything today — you are submitting a file we hand you, so we can
# confirm the pipeline works for you specifically.

# %% [markdown]
# ---
#
# ## Step 6a — Confirm the notebook is using your Python
#
# You already checked Python in a terminal (README Step 2). Run the cell below and
# compare — it shows which Python this notebook is running.

# %%
import sys

print("Python version:", sys.version.split()[0])
print("Running from:  ", sys.executable)

# %% [markdown]
# The two versions do not have to match exactly — your editor may be running a
# different install. If they differ a lot, or the cell errors, flag it now.

# %%
# A quick sanity check that Python is really working
print(2 + 2)
print("hello, MATH 170")

# %% [markdown]
# ---
#
# ## Step 6b — Run the code you were given
#
# `calculator.py` sits in this same folder. It is finished code — a small calculator
# that evaluates expressions like `1 + 2 * 3`.
#
# Run the cell below to try it. You are not expected to understand how it works
# yet; we will build up to it over the term.

# %%
from calculator import Calculator

calc = Calculator()

print("1 + 1        =", calc.eval("1 + 1"))
print("(1 + 1) * 4  =", calc.eval("(1 + 1) * 4"))
print("1 + 1 * 8    =", calc.eval("1 + 1 * 8"))

# %% [markdown]
# If those printed `2`, `8`, and `9`, the file works and is ready to submit.
#
# **If you got an error:** make sure `calculator.py` is in the same folder as this
# notebook.

# %% [markdown]
# ---
#
# ## Next: Steps 7 and 8 in the README
#
# You are done with the notebook. Go back to the
# [README](README.md) for the last two steps:
#
# - **Step 7** — save your work to GitHub (`git add` / `git commit` / `git push`)
# - **Step 8** — submit on Gradescope, either by uploading `calculator.py` or by
#   connecting your repository
#
# Submitting on Gradescope is what counts. Pushing to GitHub does not submit.

# %% [markdown]
# ---
#
# ## Before you leave
#
# Before you leave:
#
# - [ ] GitHub account created
# - [ ] Python runs (Step 2 printed a version)
# - [ ] Gradescope shows **100 / 100** for Lab 01
# - [ ] You signed the attendance sheet
#
# If any box is unchecked, ask now. Everything in this course builds on today.
#
# There is an optional **Try at home** section at the end of the
# [README](README.md) — the GitHub Student Developer Pack, and installing Python
# locally if you worked on someone else's machine.
#
# ---
#
# ### Next week
#
# We start writing our own code, and you will submit your own work instead of a
# file that was handed to you.
